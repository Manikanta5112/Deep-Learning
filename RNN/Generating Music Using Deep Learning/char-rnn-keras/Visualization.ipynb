# %%
# %matplotlib inline

import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import pandas as pd

# %%
df = pd.read_csv('logs/training_log.csv')
df
# Out:
#     epoch      loss       acc
# 0       1  3.526978  0.135052
# 1       2  3.048928  0.209728
# 2       3  2.211975  0.380642
# 3       4  1.804652  0.478027
# 4       5  1.627347  0.520206
# ..    ...       ...       ...
# 95     96  0.044539  0.989475
# 96     97  0.025556  0.995985
# 97     98  0.018711  0.997838
# 98     99  0.015268  0.998504
# 99    100  0.012973  0.999031
#
# [100 rows x 3 columns]

# %%
sns.set()

# %%
plt.figure(figsize=(10, 8))
plt.plot(df['epoch'], df['loss'])
plt.title('Training Loss over Epochs')
plt.show()

# %%
plt.figure(figsize=(10, 8))
plt.plot(df['epoch'], df['acc'])
plt.title('Training Accuracy over Epochs')
plt.show()
